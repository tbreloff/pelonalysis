# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# this shows the last expression, even if its an assignment
# other options here: https://ipython.readthedocs.io/en/stable/config/options/terminal.html#configtrait-InteractiveShell.ast_node_interactivity
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "last_expr_or_assign"

# %%
# this block ensures we can see the pelonalysis library code
import sys, os
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
import pelonalysis

# %%
# load the data... note this expects the file at /path/to/pelonalysis/data/data.csv... pass in your filename if its elsewhere
df = pelonalysis.load_dataframe()
df.head(1)
# Out:
#                           Workout Timestamp Live/On-Demand Instructor Name  \
# time
# 2020-03-30 17:06:00  2020-03-30 17:06 (EST)      On Demand   Emma Lovewell
#
#                      Length (minutes) Fitness Discipline   Type  \
# time
# 2020-03-30 17:06:00                30            Cycling  Music
#
#                                 Title         Class Timestamp  Total Output  \
# time
# 2020-03-30 17:06:00  30 min Rock Ride  2020-02-27 12:17 (EST)         329.0
#
#                      Avg. Watts Avg. Resistance  Avg. Cadence (RPM)  \
# time
# 2020-03-30 17:06:00       183.0             49%                80.0
#
#                      Avg. Speed (mph)  Distance (mi)  Calories Burned  \
# time
# 2020-03-30 17:06:00             19.84           9.91            472.0
#
#                      Avg. Heartrate  Avg. Incline  Avg. Pace (min/mi)
# time
# 2020-03-30 17:06:00             NaN           NaN                 NaN

# %%
df.describe()
# Out:
#        Length (minutes)  Total Output  Avg. Watts  Avg. Cadence (RPM)  \
# count        318.000000    137.000000  135.000000          135.000000
# mean          17.924528    369.240876  218.822222           75.740741
# std           13.559099    216.214440   71.529022            9.650584
# min            5.000000      9.000000   15.000000           18.000000
# 25%            5.000000    157.000000  204.000000           72.500000
# 50%           10.000000    432.000000  239.000000           76.000000
# 75%           30.000000    510.000000  266.000000           80.500000
# max           60.000000    745.000000  337.000000          101.000000
#
#        Avg. Speed (mph)  Distance (mi)  Calories Burned  Avg. Heartrate  \
# count        137.000000     137.000000        300.00000             0.0
# mean          21.058759       9.381314        296.33000             NaN
# std            3.726453       5.208692        320.04913             NaN
# ...

# %%
cyc = pelonalysis.filter_to_cycling(df)
running = pelonalysis.filter_to_running(df)
ftp = pelonalysis.filter_to_ftp_tests(df)
# Out:
#                           Workout Timestamp Live/On-Demand Instructor Name  \
# time
# 2020-06-04 12:50:00  2020-06-04 12:50 (EST)      On Demand    Denis Morton
# 2020-10-07 17:10:00  2020-10-07 17:10 (EST)      On Demand    Olivia Amato
# 2021-01-23 10:45:00  2021-01-23 10:45 (EST)      On Demand    Matt Wilpers
#
#                      Length (minutes) Fitness Discipline        Type  \
# time
# 2020-06-04 12:50:00                20            Cycling  Power Zone
# 2020-10-07 17:10:00                20            Cycling  Power Zone
# 2021-01-23 10:45:00                20            Cycling  Power Zone
#
#                                     Title         Class Timestamp  \
# time
# 2020-06-04 12:50:00  20 min FTP Test Ride  2019-12-04 11:00 (EST)
# 2020-10-07 17:10:00  20 min FTP Test Ride  2020-01-18 14:00 (EST)
# 2021-01-23 10:45:00  20 min FTP Test Ride  2021-01-03 08:45 (EST)
#
#                      Total Output  Avg. Watts Avg. Resistance  \
# time
# ...

# %%
pelonalysis.plot_workouts_vs_ftp(df)

# %%
pelonalysis.minutes_barh_by_group(df, 'Instructor Name', figsize=(10,10))

# %%
pelonalysis.barh_by_group(df, 'Fitness Discipline', figsize=(10,5))

# %%
pelonalysis.barh_by_group(df, 'Live/On-Demand', figsize=(10,2))
